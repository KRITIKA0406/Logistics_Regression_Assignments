# %% [markdown]
#                          Questions And Answers

# %% [markdown]
# #1.What is Simple Linear Regression (SLR)? Explain its purpose.
# #ans:-Simple Linear Regression (SLR) is a statistical method used to model and analyze the relationship between two variables:
#
# One independent variable (X) — the predictor or explanatory variable
#
# One dependent variable (Y) — the response or outcome variable
#
# 🔹 Definition
#
# Simple Linear Regression aims to find the best-fitting straight line (called the regression line) that describes how the dependent variable
# 𝑌
# Y changes as the independent variable
# 𝑋
# X changes.
#
# The model is expressed mathematically as:
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
#
# Where:
#
# 𝑌
# Y: Dependent variable
#
# 𝑋
# X: Independent variable
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : Intercept (value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0)
#
# 𝛽
# 1
# β
# 1
# 	​
#
# : Slope (change in
# 𝑌
# Y for one unit change in
# 𝑋
# X)
#
# 𝜀
# ε: Error term (captures randomness or unexplained variation)
#
# 🔹 Purpose of Simple Linear Regression
#
# The main purposes of SLR are:
#
# Prediction
#
# To predict the value of the dependent variable
# 𝑌
# Y based on a known value of
# 𝑋
# X.
#
# Example: Predicting a person’s weight (Y) from their height (X).
#
# Understanding Relationships
#
# To determine whether and how strongly two variables are related.
#
# The slope
# 𝛽
# 1
# β
# 1
# 	​
#
#  indicates the direction (positive or negative) and strength of the relationship.
#
# Quantifying Effects
#
# To estimate how much
# 𝑌
# Y changes when
# 𝑋
# X changes by one unit.

# %% [markdown]
# #2.What are the key assumptions of Simple Linear Regression?
# #ans:-The key assumptions of Simple Linear Regression (SLR) ensure that the model’s estimates and inferences (like slope, intercept, and predictions) are valid and reliable.
#
# Here are the main assumptions, usually summarized under the “LINE” framework:
#
# 🔹 1. Linearity
#
# The relationship between the independent variable (X) and the dependent variable (Y) is linear.
#
# This means the change in
# 𝑌
# Y is proportional to the change in
# 𝑋
# X.
#
# Check: Scatterplot of
# 𝑋
# X vs
# 𝑌
# Y should show a roughly straight-line pattern.
#
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
# 🔹 2. Independence of Errors
#
# The residuals (errors) are independent of each other.
#
# In other words, one observation’s error does not influence another’s.
#
# Check: Residuals vs. time (for time series) should show no clear pattern.
#
# Violation example: Autocorrelation in time series data.
#
# 🔹 3. Homoscedasticity (Constant Variance of Errors)
#
# The variance of the residuals (
# 𝜀
# ε) is constant across all levels of
# 𝑋
# X.
#
# This means the spread of errors should be roughly the same for all predicted values.
#
# Check: Plot residuals vs. predicted values — should look like a random cloud (no funnel shape).
#
# Violation: Heteroscedasticity — when the variance of errors increases or decreases with
# 𝑋
# X.
#
# 🔹 4. Normality of Errors
#
# The residuals (errors) are normally distributed with a mean of zero.
#
# This assumption is mainly important for hypothesis testing and confidence intervals, not for making predictions.
#
# Check: Histogram or Q–Q plot of residuals — should resemble a normal distribution.
#
# 🔹 5. No (or minimal) Measurement Error in X
#
# The independent variable
# 𝑋
# X should be measured accurately and without error.
#
# Measurement error in
# 𝑋
# X can bias the estimates of the slope (
# 𝛽
# 1
# β
# 1
# 	​
#
# ).

# %% [markdown]
# #3. Write the mathematical equation for a simple linear regression model and
# explain each term.
# Answer:The mathematical equation for a Simple Linear Regression (SLR) model is:
#
# 𝑌
# 𝑖
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# +
# 𝜀
# 𝑖
# Y
# i
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
# +ε
# i
# 	​
#
# 🔹 Explanation of Each Term
# Term	Name	Meaning
#
# 𝑌
# 𝑖
# Y
# i
# 	​
#
# 	Dependent variable (response)	The value of the outcome variable for the i-th observation (what we want to predict or explain).
#
# 𝑋
# 𝑖
# X
# i
# 	​
#
# 	Independent variable (predictor)	The value of the explanatory variable for the i-th observation (what we use to make predictions).
#
# 𝛽
# 0
# β
# 0
# 	​
#
# 	Intercept (constant term)	The expected (predicted) value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0. It represents where the regression line crosses the Y-axis.
#
# 𝛽
# 1
# β
# 1
# 	​
#
# 	Slope (regression coefficient)	The amount by which
# 𝑌
# Y changes, on average, for a one-unit increase in
# 𝑋
# X. It indicates the direction and strength of the relationship.
#
# 𝜀
# 𝑖
# ε
# i
# 	​
#
# 	Error term (residual)	The difference between the actual value of
# 𝑌
# 𝑖
# Y
# i
# 	​
#
#  and the value predicted by the model. It represents random variation or factors not captured by
# 𝑋
# X.
# 🔹 Interpretation
#
# The model states that each observed value
# 𝑌
# 𝑖
# Y
# i
# 	​
#
#  can be expressed as the sum of two parts:
#
# A systematic (explained) part:
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
#
# A random (unexplained) part:
# 𝜀
# 𝑖
# ε
# i
# 	​
#
#
# The fitted regression line (the line of best fit) is:
#
# 𝑌
# 𝑖
# ^
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# Y
# i
# 	​
#
# ^
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
#
# where
# 𝑌
# 𝑖
# ^
# Y
# i
# 	​
#
# ^
# 	​
#
#  is the predicted value of
# 𝑌
# 𝑖
# Y
# i
# 	​
#
# .
#
# 🔹 Example
#
# Suppose you are modeling the relationship between hours studied (X) and exam score (Y):
#
# Exam Score
# =
# 50
# +
# 5
# ×
# (
# Hours Studied
# )
# +
# 𝜀
# Exam Score=50+5×(Hours Studied)+ε
#
# 𝛽
# 0
# =
# 50
# β
# 0
# 	​
#
# =50: If a student studies 0 hours, the expected score is 50.
#
# 𝛽
# 1
# =
# 5
# β
# 1
# 	​
#
# =5: Each additional hour of study increases the exam score by 5 points (on average).
#
# 𝜀
# ε: Random variation in scores due to other unmeasured factors (e.g., sleep, stress, etc.).

# %% [markdown]
# #4.Provide a real-world example where simple linear regression can be applied.
# #ans;-Here’s a real-world example of how Simple Linear Regression (SLR) can be applied 👇
#
# 🎓 Example: Predicting Student Exam Scores from Study Hours
# Scenario:
#
# A teacher wants to understand how the number of hours students study affects their exam scores.
# They collect data from several students on:
#
# Independent variable (X): Hours studied
#
# Dependent variable (Y): Exam scores
#
# Goal:
#
# To build a simple linear regression model that predicts a student’s exam score based on how many hours they study.
#
# Model Equation:
# Exam Score
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# ×
# Study Hours
# +
# 𝜀
# Exam Score=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# ×Study Hours+ε
#
# After fitting the model using collected data, suppose we get:
#
# Exam Score
# =
# 45
# +
# 6
# ×
# Study Hours
# Exam Score=45+6×Study Hours
# Interpretation:
#
# Intercept (
# 𝛽
# 0
# =
# 45
# β
# 0
# 	​
#
# =45):
# If a student doesn’t study at all (0 hours), their expected score is 45.
#
# Slope (
# 𝛽
# 1
# =
# 6
# β
# 1
# 	​
#
# =6):
# For each additional hour of study, the exam score increases by 6 points on average.
#
# Prediction Example:
#
# If a student studies for 5 hours, their predicted exam score is:
#
# 𝑌
# ^
# =
# 45
# +
# 6
# (
# 5
# )
# =
# 75
# Y
# ^
# =45+6(5)=75
# Purpose of the Model:
#
# Prediction: Estimate exam scores based on study time.
#
# Understanding relationships: Quantify how strongly studying influences performance.
#
# Decision-making: Help students plan how much time to study to reach a target score.
#
# ✅ Other Real-World Examples of SLR:
#
# Predicting house price (Y) from size in square feet (X).
#
# Estimating sales revenue (Y) from advertising spending (X).
#
# Forecasting fuel consumption (Y) from vehicle speed (X).
#
# Predicting employee productivity (Y) based on hours of training (X).

# %% [markdown]
# #5.What is the method of least squares in linear regression?
# #ans:-The Method of Least Squares is the most common technique used to estimate the parameters (slope and intercept) in a linear regression model.
#
# It finds the best-fitting line through the data by minimizing the sum of the squared differences between the observed values and the predicted values from the regression line.
#
# 🔹 Mathematical Explanation
#
# In a simple linear regression model:
#
# 𝑌
# 𝑖
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# +
# 𝜀
# 𝑖
# Y
# i
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
# +ε
# i
# 	​
#
#
# where:
#
# 𝑌
# 𝑖
# Y
# i
# 	​
#
# : actual (observed) value
#
# 𝑌
# 𝑖
# ^
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# 𝑖
# Y
# i
# 	​
#
# ^
# 	​
#
# =β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# i
# 	​
#
# : predicted value
#
# 𝜀
# 𝑖
# =
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# ε
# i
# 	​
#
# =Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# : residual (error)
#
# 🔹 Objective of the Least Squares Method
#
# We want to find the values of
# 𝛽
# 0
# β
# 0
# 	​
#
#  and
# 𝛽
# 1
# β
# 1
# 	​
#
#  that minimize the total squared error:
#
# Minimize
# 𝑆
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝛽
# 0
# −
# 𝛽
# 1
# 𝑋
# 𝑖
# )
# 2
# Minimize S=
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
# =
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −β
# 0
# 	​
#
# −β
# 1
# 	​
#
# X
# i
# 	​
#
# )
# 2
#
# This quantity
# 𝑆
# S is called the sum of squared residuals (SSR).
#
# 🔹 Least Squares Estimates
#
# By taking partial derivatives of
# 𝑆
# S with respect to
# 𝛽
# 0
# β
# 0
# 	​
#
#  and
# 𝛽
# 1
# β
# 1
# 	​
#
#  and setting them to zero, we get:
#
# 𝛽
# 1
# ^
# =
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# β
# 1
# 	​
#
# ^
# 	​
#
# =
# ∑(X
# i
# 	​
#
# −
# X
# ˉ
# )
# 2
# ∑(X
# i
# 	​
#
# −
# X
# ˉ
# )(Y
# i
# 	​
#
# −
# Y
# ˉ
# )
# 	​
#
# 𝛽
# 0
# ^
# =
# 𝑌
# ˉ
# −
# 𝛽
# 1
# ^
# 𝑋
# ˉ
# β
# 0
# 	​
#
# ^
# 	​
#
# =
# Y
# ˉ
# −
# β
# 1
# 	​
#
# ^
# 	​
#
# X
# ˉ
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
# : mean of X values
#
# 𝑌
# ˉ
# Y
# ˉ
# : mean of Y values
#
# 🔹 Intuitive Meaning
#
# The method of least squares finds the line that makes the vertical distances (errors) between the actual points and the line as small as possible — in a squared sense.
#
# Squaring the errors ensures that:
#
# Positive and negative errors don’t cancel out.
#
# Larger errors are penalized more heavily.
#
# 🔹 Graphical Illustration
#
# Imagine plotting your data points on a scatterplot, then drawing different possible lines through them.
# The least squares regression line is the one that minimizes the sum of squared distances between each data point and the line.
#
# 🔹 Purpose and Advantages
# Purpose	Explanation
# Estimate model parameters	Find the best values for
# 𝛽
# 0
# β
# 0
# 	​
#
#  and
# 𝛽
# 1
# β
# 1
# 	​
#
#
# Best fit line	Ensures smallest possible total prediction error
# Foundation for inference	Enables hypothesis testing and confidence intervals in regression

# %% [markdown]
# #6. What is Logistic Regression? How does it differ from Linear Regression?
# #ans:-🔹 What is Logistic Regression?
#
# Logistic Regression is a statistical method used to model the relationship between one or more independent variables (predictors) and a categorical dependent variable — typically a binary outcome (e.g., Yes/No, 0/1, Success/Failure).
#
# Despite its name, logistic regression is used for classification, not regression.
#
# 🔹 Purpose
#
# Logistic Regression is used to predict the probability that an observation belongs to a particular category.
#
# For example:
#
# Will a customer buy (1) or not buy (0) a product?
#
# Will a patient have a disease (1) or not (0)?
#
# Will an email be spam (1) or not spam (0)?
#
# 🔹 Mathematical Form
#
# The model predicts the probability (p) that
# 𝑌
# =
# 1
# Y=1 using the logistic (sigmoid) function:
#
# 𝑝
# =
# 𝑃
# (
# 𝑌
# =
# 1
# ∣
# 𝑋
# )
# =
# 1
# 1
# +
# 𝑒
# −
# (
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# )
# p=P(Y=1∣X)=
# 1+e
# −(β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X)
# 1
# 	​
#
#
# Taking the logit (log-odds) transformation gives a linear relationship:
#
# ln
# ⁡
# (
# 𝑝
# 1
# −
# 𝑝
# )
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# ln(
# 1−p
# p
# 	​
#
# )=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
#
# where:
#
# 𝑝
# p: probability of success (Y = 1)
#
# 𝛽
# 0
# β
# 0
# 	​
#
# : intercept
#
# 𝛽
# 1
# β
# 1
# 	​
#
# : coefficient showing how X affects the log-odds of Y = 1
#
# 🔹 Key Differences: Logistic vs. Linear Regression
# Feature	Linear Regression	Logistic Regression
# Dependent Variable	Continuous (e.g., income, weight)	Categorical (usually binary: 0 or 1)
# Purpose	Predicts a numerical value	Predicts probability or class label
# Equation
# 𝑌
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# +
# 𝜀
# Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X+ε
# ln
# ⁡
# (
# 𝑝
# 1
# −
# 𝑝
# )
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑋
# ln(
# 1−p
# p
# 	​
#
# )=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# Output Range
# 𝑌
# ∈
# (
# −
# ∞
# ,
# +
# ∞
# )
# Y∈(−∞,+∞)
# 𝑝
# ∈
# (
# 0
# ,
# 1
# )
# p∈(0,1)
# Error Term	Assumed normally distributed	Assumed binomially distributed
# Fitted Line	Straight line	S-shaped (sigmoid) curve
# Use Case	Regression problems	Classification problems
# 🔹 Example
#
# Scenario: Predict whether a student passes (1) or fails (0) an exam based on study hours (X).
#
# Linear Regression might predict:
#
# Score
# =
# 45
# +
# 6
# ×
# Hours
# Score=45+6×Hours
#
# → produces continuous scores (e.g., 70, 85, etc.).
#
# Logistic Regression predicts:
#
# 𝑝
# (
# Pass
# )
# =
# 1
# 1
# +
# 𝑒
# −
# (
# −
# 4
# +
# 1.2
# ×
# Hours
# )
# p(Pass)=
# 1+e
# −(−4+1.2×Hours)
# 1
# 	​
#
#
# → produces a probability (e.g., 0.85 = 85% chance of passing).

# %% [markdown]
# #7.Name and briefly describe three common evaluation metrics for regression
# models.
# Answer:Three Common Evaluation Metrics for Regression Models
#
# When evaluating regression models, we use metrics that measure how well the predicted values match the actual values.
# Here are three of the most common ones 👇
#
# 🔹 1. Mean Absolute Error (MAE)
# MAE
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# ∣
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# ∣
# MAE=
# n
# 1
# 	​
#
# i=1
# ∑
# n
# 	​
#
# ∣Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# ∣
#
# Meaning: The average of the absolute differences between actual (
# 𝑌
# 𝑖
# Y
# i
# 	​
#
# ) and predicted (
# 𝑌
# 𝑖
# ^
# Y
# i
# 	​
#
# ^
# 	​
#
# ) values.
#
# Interpretation: It tells us, on average, how much the predictions deviate from the actual values.
#
# Advantage: Easy to understand because it’s in the same units as the data.
#
# 🔹 2. Mean Squared Error (MSE)
# MSE
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# MSE=
# n
# 1
# 	​
#
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
#
# Meaning: The average of the squared differences between actual and predicted values.
#
# Interpretation: Measures how far the predictions are from the actual values, penalizing larger errors more heavily.
#
# Disadvantage: The result is in squared units, which may be less intuitive.
#
# 🔹 3. Root Mean Squared Error (RMSE)
# RMSE
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# 𝑖
# ^
# )
# 2
# RMSE=
# n
# 1
# 	​
#
# i=1
# ∑
# n
# 	​
#
# (Y
# i
# 	​
#
# −
# Y
# i
# 	​
#
# ^
# 	​
#
# )
# 2
# 	​
#
#
# Meaning: The square root of MSE — it brings the metric back to the same unit as the target variable.
#
# Interpretation: Represents the standard deviation of prediction errors — smaller RMSE indicates better model performance.

# %% [markdown]
# #8.What is the purpose of the R-squared metric in regression analysis?
# #ans:-R-squared ( R2R^2R2 ), also known as the coefficient of determination, measures how well the regression model explains the variability of the dependent variable.
# R2=1−SSresSStotR^2 = 1 - \frac{\text{SS}_{\text{res}}}{\text{SS}_{\text{tot}}}R2=1−SStot​SSres​​
# Where:
#
#
# SSres=∑(Yi−Yi^)2\text{SS}_{\text{res}} = \sum (Y_i - \hat{Y_i})^2SSres​=∑(Yi​−Yi​^​)2 → residual (unexplained) sum of squares
#
#
# SStot=∑(Yi−Yˉ)2\text{SS}_{\text{tot}} = \sum (Y_i - \bar{Y})^2SStot​=∑(Yi​−Yˉ)2 → total variation in the data
#
#
#
# 🔹 Purpose:
#
#
# To show how much of the variance in the dependent variable (YYY) is explained by the model.
#
#
# It provides a measure of goodness of fit.
#
#
#
# 🔹 Interpretation:
#
#
# R2=0R^2 = 0R2=0: Model explains none of the variance.
#
#
# R2=1R^2 = 1R2=1: Model explains all of the variance perfectly.
#
#
# Higher R2R^2R2 means the model fits the data better.
#
#
#
# 🔹 Example:
# If R2=0.85R^2 = 0.85R2=0.85, it means:
#
# 85% of the variation in the dependent variable is explained by the independent variable(s), while 15% remains unexplained (due to random error or other factors).
#
#
# ✅ In short:
#
#
# Regression metrics (MAE, MSE, RMSE) measure how accurate predictions are.
#
#
# R-squared measures how well the model explains the data’s variability — a key indicator of model fit.

# %% [markdown]
# #9. Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
# (Include your Python code and output in the code box below.)

# %%
# Import necessary libraries
from sklearn.linear_model import LinearRegression
import numpy as np

# Example data
# Independent variable (X): Hours studied
# Dependent variable (Y): Exam scores
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([45, 50, 55, 60, 65])

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, Y)

# Print the slope (coefficient) and intercept
print("Slope (β1):", model.coef_[0])
print("Intercept (β0):", model.intercept_)
# Out:
# Slope (β1): 4.999999999999999
# Intercept (β0): 40.0

# %% [markdown]
# #10.How do you interpret the coefficients in a simple linear regression model?
# #ans:-Y=β
# 0
# 	​
#
# +β
# 1
# 	​
#
# X
# Coefficient	Name	Interpretation
# β₀ (Intercept)	Constant term	The expected value of
# 𝑌
# Y when
# 𝑋
# =
# 0
# X=0. It represents where the regression line crosses the Y-axis.
# β₁ (Slope)	Regression coefficient	The average change in
# 𝑌
# Y for a one-unit increase in
# 𝑋
# X. It indicates the direction (positive/negative) and magnitude of the relationship.
# Example Interpretation (from the code above):
# Exam Score
# =
# 40
# +
# 5
# ×
# (
# Hours Studied
# )
# Exam Score=40+5×(Hours Studied)
#
# Intercept (40): If a student studies 0 hours, the expected exam score is 40.
#
# Slope (5): For each additional hour of study, the exam score increases by 5 points on average.
